# %% [markdown]
# ## Version Control
# - It takes snapshot of changes you make in your code and keep it, so, later on, you can go back and check,
#  correct or modify things.
# - Rollback basically.
# - It allows collabarations. (after connecting with github)
# - Other can share, clone, pull your code and view changes made by you or vice versa.
